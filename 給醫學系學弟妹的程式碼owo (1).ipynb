# %%
import torch
import torchvision.transforms as transforms
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

# 函數從網址加載圖片
def load_image(url):
    response = requests.get(url)
    return Image.open(BytesIO(response.content))

# 定義變換
transforms_dict = {
    "Original Image": None,
    "Resized": transforms.Resize((1024,1920)),
    "Center Cropped": transforms.CenterCrop(400),
    "Color Jittered": transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5),
    "Horizontally Flipped": transforms.RandomHorizontalFlip(p=1),
    "Randomly Rotated": transforms.RandomRotation(45)
}

# 加載圖片
img_url ='https://scontent.xx.fbcdn.net/v/t39.30808-6/400797805_250703444670572_7224810866872125591_n.jpg?_nc_cat=106&ccb=1-7&_nc_sid=5f2048&_nc_ohc=5xl7CSLAsA0AX_51A7q&_nc_ht=scontent.ftpe8-3.fna&oh=00_AfCLp0T_vCuyUT5i0Z5OcPTR9lum6uudR2QcLBtQc93TDA&oe=6557DD70&_nc_fr=ftpe8c03'
img = load_image(img_url)

# 準備繪圖
fig, ax = plt.subplots(1, 6, figsize=(15, 5))  # 1 row，6 column

# 繪製和顯示變換後的圖像
for i, (title, transform) in enumerate(transforms_dict.items()):
    transformed_img = img
    if transform:
        transformed_img = transform(transformed_img)
    ax[i].imshow(transformed_img)
    ax[i].set_title(title)
    ax[i].axis('off')

plt.tight_layout()
plt.show()

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

# 函數從網址加載圖片
def load_image(url):
    response = requests.get(url)
    return Image.open(BytesIO(response.content))

# 定義變換
transforms_dict = {
    "Original Image": None,
    "Resized": transforms.Resize((1024,1920)),
    "Center Cropped": transforms.CenterCrop(200),
    "Color Jittered": transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5),
    "Horizontally Flipped": transforms.RandomHorizontalFlip(p=1),
    "Randomly Rotated": transforms.RandomRotation(30)
}

# 加載圖片
img_url = 'https://scontent.ftpe8-3.fna.fbcdn.net/v/t39.30808-6/400422206_740772498093921_6519532954084879523_n.jpg?_nc_cat=107&ccb=1-7&_nc_sid=5f2048&_nc_ohc=FmBreSrB-uYAX8yLg6A&_nc_ht=scontent.ftpe8-3.fna&oh=00_AfBJCM5oTSn5rNp7fb1iLCgfXfR_Ixg5lZLLRhvY3m5f-w&oe=6557D332'
img = load_image(img_url)

# 準備繪圖
fig, ax = plt.subplots(1, 6, figsize=(15, 5))  # 1 row，6 column

# 繪製和顯示變換後的圖像
for i, (title, transform) in enumerate(transforms_dict.items()):
    transformed_img = img
    if transform:
        transformed_img = transform(transformed_img)
    ax[i].imshow(transformed_img, cmap='gray')
    ax[i].set_title(title)
    ax[i].axis('off')

plt.tight_layout()
plt.show()
